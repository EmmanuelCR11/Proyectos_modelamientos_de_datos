# %% [markdown]
# 01.especiacion_agua.ipynb
#
# ###Efecto del Aumento de CO₂ Atmosférico sobre el pH del Océano
# Objetivo
# Simular cómo cambia el pH del agua de mar a medida que aumenta la concentración de dióxido de carbono (CO₂) en la atmósfera, un fenómeno directamente asociado al calentamiento global y la acidificación oceánica.
#
# Contexto
# La concentración actual de CO₂ en la atmósfera es de aproximadamente 420 ppm, lo que equivale a una presión parcial de alrededor de log P(CO₂) = -3.5 en atmósferas.
#
# Se espera que, si las emisiones continúan, las concentraciones de CO₂ puedan aumentar hasta:
#
# 560 ppm (~doble preindustrial): log P(CO₂) ≈ -3.25
# 840 ppm (escenario extremo): log P(CO₂) ≈ -3.0
# El aumento de CO₂ provoca un descenso del pH oceánico debido a su disolución y formación de ácido carbónico:
#
#
# Este ejercicio permite explorar este efecto en equilibrio, utilizando una solución marina simplificada.
#
# Instrucciones
# Simula tres escenarios con diferente presión parcial de CO₂:
#
# Condición actual: log P(CO₂) = -3.5 (≈ 420 ppm)
# Escenario de emisiones moderadas: log P(CO₂) = -3.25 (≈ 560 ppm)
# Escenario extremo: log P(CO₂) = -3.0 (≈ 840 ppm)
# Observa los cambios en:
#
# pH
# Distribución de especies de carbono (CO₂, HCO₃⁻, CO₃²⁻)
# Índice de saturación de calcita o aragonita
#
#
# SOLUCION:
# CREO EL NANO
#
#
# ![image.png](attachment:b4ade1a0-bfc8-4b0c-b689-bbfda3c4cf8e.png)
#
#
# OBSERVO LOS RESULTADOS ARROJADOS POR EL PROGRAMA:
#
#
# ![image.png](attachment:7a125788-483d-45e6-97e0-8893b6c69f78.png)
#
#
# INTERPRETACION:
# Los resultados obtenidos evidencian que el incremento de la presión parcial de CO₂ atmosférico produce una disminución progresiva del pH del agua de mar, pasando de valores cercanos a 8.31 en condiciones actuales hasta aproximadamente 7.87 en el escenario extremo. Este comportamiento confirma el proceso de acidificación oceánica asociado al aumento de CO₂ disuelto. Asimismo, se observa un incremento en la concentración de CO₂ acuoso y del ion bicarbonato (HCO₃⁻), mientras que el ion carbonato (CO₃²⁻) disminuye de manera significativa. Esta reducción del carbonato tiene un efecto directo sobre los índices de saturación de calcita y aragonita, los cuales disminuyen notablemente, indicando condiciones menos favorables para la precipitación de carbonato de calcio. En conjunto, estos resultados reflejan un impacto negativo del aumento de CO₂ sobre la química del océano y sobre los organismos marinos calcificadores.

# %% [markdown]
# 02.equilibrio_phase.ipynb
# Solucion:
# creo sistema abierto + cerrado en un nano
#
#
# ![image.png](attachment:a0776800-933f-4ae9-b941-fa840372d2ee.png)
#
#
# resultados:
#
# ![image.png](attachment:c32066a5-3708-41ca-8f1c-a284fae50d84.png)
#
# interpretacion
# sim 1  pH 9.9065  Ca = 1.22e-04 → C(4) = 1.22e-04
# sim 2  pH 8.2786  Ca = 4.90e-04 → C(4) = 9.75e-04
#
# El sistema abierto al CO₂ presenta una mayor disolución de calcita, lo cual se evidencia en una mayor concentración de Ca²⁺ en solución. Esto ocurre porque el CO₂ atmosférico genera ácido carbónico, aumentando la acidez del sistema y favoreciendo la disolución del CaCO₃. En contraste, el sistema cerrado presenta un pH más alto y menor concentración de calcio disuelto, lo que indica una menor disolución de la calcita.

# %% [markdown]
# 03.water_mixing.ipynb
# solucion;
# creo el nano
#
# ![image.png](attachment:fc97c2e3-9f3b-487b-8aeb-d64dc681a811.png)
#
# resultados
#
#
# ![image.png](attachment:52e6a1b0-37ca-4d65-b1a9-12d28a2bb0c8.png)
#
# Los resultados de la mezcla entre agua de mar y agua de acuífero muestran una disminución progresiva del pH y del índice de saturación de la calcita a medida que aumenta la proporción de agua subterránea. El agua de mar presenta condiciones sobresaturadas (SI > 0), mientras que el acuífero se encuentra subsaturado (SI < 0), lo que favorece la disolución de calcita. En las mezclas intermedias se observa una transición desde condiciones de sobresaturación hacia subsaturación, identificándose el punto de equilibrio alrededor del 50% de mezcla. A partir de este punto, el sistema presenta condiciones favorables para la karstificación, evidenciando que la interacción entre agua marina y agua dulce puede intensificar los procesos de disolución en acuíferos costeros.

# %% [markdown]
# ## 04.adsorption.ipynb
# En el modelo de PHREEQC, el intercambiador se define como CaX₂ con una cantidad de 0.03 moles. Dado que cada mol de CaX₂ contiene dos sitios de intercambio X, esto equivale a 0.06 moles (60 mmol). Por lo tanto, la afirmación de que el sistema contiene 4 mmol de intercambiador es falsa.
#
# nano:
#
#
# ![image.png](attachment:d9a3a1f7-6d94-4dc8-85da-9738019ae665.png)
#
# respuesta
# En el modelo de PHREEQC, el intercambiador se define como CaX₂ con una cantidad de 0.03 moles. Dado que cada mol de CaX₂ contiene dos sitios de intercambio X, esto equivale a 0.06 moles (60 mmol). Por lo tanto, la afirmación de que el sistema contiene 4 mmol de intercambiador es falsa.
